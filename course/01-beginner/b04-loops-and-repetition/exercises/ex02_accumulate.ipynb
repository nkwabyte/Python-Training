# %% [markdown]
# # Loops and repetition
#
# Loops let you repeat work without copying the same line again and again. In beginner Python, the two most common loop styles are `for` loops and `while` loops. A `for` loop is best when you already know what you are looping over, such as a range of numbers or the items in a list. A `while` loop is best when you want to keep going until a condition becomes false.
#
# The function `range()` is often used with `for`. It creates a sequence of numbers for counting. One detail matters a lot: the **stop value is not included**. So `range(5)` produces `0, 1, 2, 3, 4`. That “stop is exclusive” rule is one of the most common beginner stumbling blocks.
#
# Loops are not just for counting. They are how you add totals, search through data, repeat prompts, and build up results step by step. When a loop misbehaves, inspect three things first: the starting state, the stopping rule, and how the loop changes on each pass.
#
# ## This exercise: Exercise 2 accumulate
#
# Work through the code cell below after reading the concept notes above. Run it, inspect the result, then change values and rerun so the rule becomes concrete.
#
# ## Task
#
# Sum readings, count the values above a threshold, and keep the passing values.

# %%
from __future__ import annotations


def analyse(readings: list[int], threshold: int) -> tuple[int, int, list[int]]:
    total = 0
    above_threshold = 0
    kept: list[int] = []
    for value in readings:
        total += value
        if value > threshold:
            above_threshold += 1
            kept.append(value)
    return total, above_threshold, kept


if __name__ == "__main__":
    print(analyse([3, 8, 2, 10], 5))
