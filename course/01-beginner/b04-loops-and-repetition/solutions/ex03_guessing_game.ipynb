# %% [markdown]
# # Notebook exercise

# %%
from __future__ import annotations


def guess_until(secret: int, guesses: list[int], limit: int = 3) -> int:
    tries = 0
    for guess in guesses:
        tries += 1
        if guess == secret:
            return tries
        if tries >= limit:
            return tries
    return tries
