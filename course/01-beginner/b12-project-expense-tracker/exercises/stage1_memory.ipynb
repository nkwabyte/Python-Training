# %% [markdown]
# # Building a beginner project step by step
#
# This project brings together the earlier beginner ideas into one program that grows in stages. Instead of solving everything at once, you will build a simple version first, then improve it one step at a time. That is how most real software is developed.
#
# An expense tracker is a good beginner project because it uses several core ideas at once: collections, functions, text handling, file storage, validation, and reporting. Each stage adds one layer of complexity while keeping the earlier parts visible and understandable.
#
# When you work on a project notebook, try to notice how separate beginner topics start to connect. That is the moment where isolated exercises turn into programming skill.
#
# ## This exercise: stage1 memory
#
# Work through the code cell below after reading the concept notes above. Run it, inspect the result, then change values and rerun so the rule becomes concrete.
#
# ## Task
#
# Create a list of dictionaries, add an expense, and print it.

# %%
from __future__ import annotations


def add_expense(expenses: list[dict[str, object]], description: str, amount: float) -> None:
    expenses.append({"description": description, "amount": amount})


if __name__ == "__main__":
    expenses: list[dict[str, object]] = []
    add_expense(expenses, 'coffee', 4.5)
    print(expenses)
