# %% [markdown]
# # Notebook exercise

# %%
from __future__ import annotations


def command_loop(command: str, expenses: list[dict[str, object]]) -> float:
    if command == 'sum':
        return sum(float(item['amount']) for item in expenses)
    return 0.0
