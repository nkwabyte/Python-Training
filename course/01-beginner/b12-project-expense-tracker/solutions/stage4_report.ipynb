# %% [markdown]
# # Putting the beginner concepts together
#
# A real project brings many beginner ideas together: variables, decisions, loops, functions, collections, and file handling. This is where the concepts become practical tools for solving a problem.
#
# ```text
# expense tracker
# ├── store expenses
# ├── calculate totals
# ├── show summary
# ├── save to file
# └── repeat until user quits
# ```
#
# ### How to think about it
# Projects teach more than syntax—they teach problem solving. You start by understanding the problem, breaking it into small tasks, and then combining the concepts you have already learned into a complete workflow.
#
# ### Visual learning links
# - [Python docs — tutorial index](https://docs.python.org/3/tutorial/index.html)
# - [Python Tutor](https://pythontutor.com/visualize.html)
# - [Real Python beginner path](https://realpython.com/)
#
# ---
#
# # Notebook exercise

# %%
from __future__ import annotations


def total_expenses(expenses: list[dict[str, object]]) -> float:
    return sum(float(item['amount']) for item in expenses)
