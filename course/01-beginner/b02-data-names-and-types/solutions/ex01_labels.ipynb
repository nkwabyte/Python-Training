# %% [markdown]
# # Notebook exercise

# %%
from __future__ import annotations


def trace_names() -> dict[str, int]:
    x = 10
    y = x
    x = 99
    z = y + x
    return {"x": x, "y": y, "z": z}
