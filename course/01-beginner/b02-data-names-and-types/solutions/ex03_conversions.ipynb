# %% [markdown]
# # Notebook exercise

# %%
from __future__ import annotations


def total_cost(quantity_text: str, price_text: str) -> float:
    quantity = int(quantity_text)
    price = float(price_text)
    return quantity * price
