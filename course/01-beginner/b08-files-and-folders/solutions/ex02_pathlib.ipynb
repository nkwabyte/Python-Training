# %% [markdown]
# # Notebook exercise

# %%
from pathlib import Path


def path_info(folder: str, filename: str) -> str:
    path = Path(folder) / filename
    return f"parent={path.parent}, name={path.name}"
