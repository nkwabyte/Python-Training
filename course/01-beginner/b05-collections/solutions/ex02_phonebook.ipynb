# %% [markdown]
# # Notebook exercise

# %%
from __future__ import annotations


def phonebook() -> dict[str, str]:
    contacts = {"Ada": "111", "Linus": "222"}
    contacts["Grace"] = "333"
    return contacts
