# %% [markdown]
# # Notebook exercise

# %%
from __future__ import annotations


def total_scores(records: list[dict[str, int]]) -> list[dict[str, int]]:
    return [{"name": record["name"], "score": record["score"]} for record in records]
