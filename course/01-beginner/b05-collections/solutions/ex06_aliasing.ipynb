# %% [markdown]
# # Notebook exercise

# %%
from __future__ import annotations


def alias_demo() -> tuple[list[str], list[str]]:
    first = ["a", "b"]
    second = first
    second.append("c")
    return first, second
